# %%
# Train the model
history_cifar = model_cifar.fit(x_train_cifar_flat, y_train_cifar_one_hot,
                                  epochs=10, batch_size=32,
                                  validation_split=0.2)

# Evaluate the model on the test set
loss_cifar, accuracy_cifar = model_cifar.evaluate(x_test_cifar_flat, y_test_cifar_one_hot)
print(f"\nTest Loss (CIFAR-10): {loss_cifar:.4f}")
print(f"Test Accuracy (CIFAR-10): {accuracy_cifar:.4f}")
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 18ms/step - accuracy: 0.3166 - loss: 1.8890 - val_accuracy: 0.3742 - val_loss: 1.7426
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - accuracy: 0.3839 - loss: 1.7174 - val_accuracy: 0.4043 - val_loss: 1.6625
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.4126 - loss: 1.6385 - val_accuracy: 0.4189 - val_loss: 1.6355
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.4322 - loss: 1.5906 - val_accuracy: 0.4221 - val_loss: 1.6194
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - accuracy: 0.4464 - loss: 1.5454 - val_accuracy: 0.4367 - val_loss: 1.5779
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - accuracy: 0.4554 - loss: 1.5181 - val_accuracy: 0.4122 - val_loss: 1.6780
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - accuracy: 0.4652 - loss: 1.4917 - val_accuracy: 0.4198 - val_loss: 1.6288
# Epoch 8/10
# ...

# %% [markdown]
# ### Evaluate Results for CIFAR-10 using Confusion Matrix

# %%
# Predict the classes for the test set
y_pred_cifar_one_hot = model_cifar.predict(x_test_cifar_flat)
y_pred_cifar = np.argmax(y_pred_cifar_one_hot, axis=1)

# Generate confusion matrix
cm_cifar = confusion_matrix(y_test_cifar, y_pred_cifar)

plt.figure(figsize=(10, 8))
sns.heatmap(cm_cifar, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for CIFAR-10 ANN Model')
plt.show()

# Display classification report
print("\nClassification Report for CIFAR-10 ANN Model:")
print(classification_report(y_test_cifar, y_pred_cifar))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Classification Report for CIFAR-10 ANN Model:
#               precision    recall  f1-score   support
#
#            0       0.49      0.59      0.54      1000
#            1       0.58      0.59      0.59      1000
#            2       0.34      0.29      0.31      1000
#            3       0.32      0.27      0.29      1000
#            4       0.38      0.42      0.40      1000
#            5       0.36      0.41      0.38      1000
#            6       0.47      0.53      0.50      1000
#            7       0.69      0.42      0.52      1000
#            8       0.52      0.66      0.58      1000
#            9       0.56      0.47      0.51      1000
#
#     accuracy                           0.46     10000
#    macro avg       0.47      0.46      0.46     10000
# weighted avg       0.47      0.46      0.46     10000

# %%
# Train the model
history_cifar = model_cifar.fit(x_train_cifar_flat, y_train_cifar_one_hot,
                                  epochs=10, batch_size=32,
                                  validation_split=0.2)

# Evaluate the model on the test set
loss_cifar, accuracy_cifar = model_cifar.evaluate(x_test_cifar_flat, y_test_cifar_one_hot)
print(f"\nTest Loss (CIFAR-10): {loss_cifar:.4f}")
print(f"Test Accuracy (CIFAR-10): {accuracy_cifar:.4f}")
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.4891 - loss: 1.4201 - val_accuracy: 0.4517 - val_loss: 1.5419
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 14ms/step - accuracy: 0.4973 - loss: 1.4017 - val_accuracy: 0.4618 - val_loss: 1.5113
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.5011 - loss: 1.3914 - val_accuracy: 0.4655 - val_loss: 1.5148
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.5059 - loss: 1.3742 - val_accuracy: 0.4635 - val_loss: 1.5288
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.5114 - loss: 1.3634 - val_accuracy: 0.4775 - val_loss: 1.4941
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.5142 - loss: 1.3587 - val_accuracy: 0.4759 - val_loss: 1.4773
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.5155 - loss: 1.3516 - val_accuracy: 0.4804 - val_loss: 1.4881
# Epoch 8/10
# ...

# %% [markdown]
# ### Evaluate Results for CIFAR-10 using Confusion Matrix

# %%
# Predict the classes for the test set
y_pred_cifar_one_hot = model_cifar.predict(x_test_cifar_flat)
y_pred_cifar = np.argmax(y_pred_cifar_one_hot, axis=1)

# Generate confusion matrix
cm_cifar = confusion_matrix(y_test_cifar, y_pred_cifar)

plt.figure(figsize=(10, 8))
sns.heatmap(cm_cifar, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for CIFAR-10 ANN Model')
plt.show()

# Display classification report
print("\nClassification Report for CIFAR-10 ANN Model:")
print(classification_report(y_test_cifar, y_pred_cifar))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# Classification Report for CIFAR-10 ANN Model:
#               precision    recall  f1-score   support
#
#            0       0.52      0.59      0.55      1000
#            1       0.58      0.59      0.58      1000
#            2       0.40      0.32      0.35      1000
#            3       0.31      0.29      0.30      1000
#            4       0.50      0.26      0.34      1000
#            5       0.39      0.37      0.38      1000
#            6       0.42      0.65      0.51      1000
#            7       0.51      0.56      0.53      1000
#            8       0.74      0.40      0.52      1000
#            9       0.43      0.62      0.51      1000
#
#     accuracy                           0.47     10000
#    macro avg       0.48      0.47      0.46     10000
# weighted avg       0.48      0.47      0.46     10000

# %% [markdown]
# ### Load CIFAR-10 Dataset

# %%
# Load CIFAR-10 dataset
(x_train_cifar, y_train_cifar), (x_test_cifar, y_test_cifar) = keras.datasets.cifar10.load_data()

print(f"CIFAR Training data shape: {x_train_cifar.shape}")
print(f"CIFAR Training labels shape: {y_train_cifar.shape}")
print(f"CIFAR Test data shape: {x_test_cifar.shape}")
print(f"CIFAR Test labels shape: {y_test_cifar.shape}")
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# CIFAR Training data shape: (50000, 32, 32, 3)
# CIFAR Training labels shape: (50000, 1)
# CIFAR Test data shape: (10000, 32, 32, 3)
# CIFAR Test labels shape: (10000, 1)

# %% [markdown]
# ### Data Pre-processing for CIFAR-10

# %%
# Normalize pixel values to [0, 1]
x_train_cifar_norm = x_train_cifar.astype('float32') / 255.0
x_test_cifar_norm = x_test_cifar.astype('float32') / 255.0

# Flatten the images for ANN input (32x32x3 = 3072 features)
x_train_cifar_flat = x_train_cifar_norm.reshape(-1, 32*32*3)
x_test_cifar_flat = x_test_cifar_norm.reshape(-1, 32*32*3)

# One-hot encode the labels
y_train_cifar_one_hot = keras.utils.to_categorical(y_train_cifar, num_classes=10)
y_test_cifar_one_hot = keras.utils.to_categorical(y_test_cifar, num_classes=10)

print(f"Normalized and flattened CIFAR Training data shape: {x_train_cifar_flat.shape}")
print(f"One-hot encoded CIFAR Training labels shape: {y_train_cifar_one_hot.shape}")
print(f"Normalized and flattened CIFAR Test data shape: {x_test_cifar_flat.shape}")
print(f"One-hot encoded CIFAR Test labels shape: {y_test_cifar_one_hot.shape}")
# Out:
# Normalized and flattened CIFAR Training data shape: (50000, 3072)
# One-hot encoded CIFAR Training labels shape: (50000, 10)
# Normalized and flattened CIFAR Test data shape: (10000, 3072)
# One-hot encoded CIFAR Test labels shape: (10000, 10)

# %% [markdown]
# ### Define and Train ANN Model for CIFAR-10

# %%
# Define the ANN model for CIFAR-10
model_cifar = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(3072,)), # CIFAR images are 32x32x3 = 3072
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax') # Output layer for 10 classes
])

# Compile the model
model_cifar.compile(optimizer='adam',
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])

model_cifar.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 256)            │       786,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# ...

# %% [markdown]
# ### Define and Train ANN Model for MNIST

# %%
# Define the ANN model
model_mnist = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(784,)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax') # Output layer for 10 classes
])

# Compile the model
model_mnist.compile(optimizer='adam',
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])

model_mnist.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# ...

# %%
# Train the model
history_mnist = model_mnist.fit(x_train_mnist_flat, y_train_mnist_one_hot,
                                  epochs=10, batch_size=32,
                                  validation_split=0.2)

# Evaluate the model on the test set
loss_mnist, accuracy_mnist = model_mnist.evaluate(x_test_mnist_flat, y_test_mnist_one_hot)
print(f"\nTest Loss (MNIST): {loss_mnist:.4f}")
print(f"Test Accuracy (MNIST): {accuracy_mnist:.4f}")
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9240 - loss: 0.2568 - val_accuracy: 0.9609 - val_loss: 0.1341
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9672 - loss: 0.1077 - val_accuracy: 0.9689 - val_loss: 0.1069
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9768 - loss: 0.0747 - val_accuracy: 0.9711 - val_loss: 0.0975
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9822 - loss: 0.0563 - val_accuracy: 0.9749 - val_loss: 0.0844
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9859 - loss: 0.0440 - val_accuracy: 0.9737 - val_loss: 0.0934
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9891 - loss: 0.0340 - val_accuracy: 0.9747 - val_loss: 0.0880
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9898 - loss: 0.0303 - val_accuracy: 0.9752 - val_loss: 0.0843
# Epoch 8/10
# ...

# %% [markdown]
# ### Evaluate Results for MNIST using Confusion Matrix

# %%
# Predict the classes for the test set
y_pred_mnist_one_hot = model_mnist.predict(x_test_mnist_flat)
y_pred_mnist = np.argmax(y_pred_mnist_one_hot, axis=1)

# Generate confusion matrix
cm_mnist = confusion_matrix(y_test_mnist, y_pred_mnist)

plt.figure(figsize=(10, 8))
sns.heatmap(cm_mnist, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for MNIST ANN Model')
plt.show()

# Display classification report
print("\nClassification Report for MNIST ANN Model:")
print(classification_report(y_test_mnist, y_pred_mnist))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Classification Report for MNIST ANN Model:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.97      0.98      1032
#            3       0.98      0.97      0.97      1010
#            4       0.99      0.96      0.97       982
#            5       0.99      0.96      0.98       892
#            6       0.97      0.99      0.98       958
#            7       0.97      0.98      0.98      1028
#            8       0.97      0.98      0.97       974
#            9       0.96      0.97      0.96      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Load MNIST dataset
(x_train_mnist, y_train_mnist), (x_test_mnist, y_test_mnist) = keras.datasets.mnist.load_data()

print(f"MNIST Training data shape: {x_train_mnist.shape}")
print(f"MNIST Training labels shape: {y_train_mnist.shape}")
print(f"MNIST Test data shape: {x_test_mnist.shape}")
print(f"MNIST Test labels shape: {y_test_mnist.shape}")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# MNIST Training data shape: (60000, 28, 28)
# MNIST Training labels shape: (60000,)
# MNIST Test data shape: (10000, 28, 28)
# MNIST Test labels shape: (10000,)

# %% [markdown]
# ### Data Pre-processing for MNIST

# %%
# Normalize pixel values to [0, 1]
x_train_mnist_norm = x_train_mnist.astype('float32') / 255.0
x_test_mnist_norm = x_test_mnist.astype('float32') / 255.0

# Flatten the images for ANN input (28x28 = 784 features)
x_train_mnist_flat = x_train_mnist_norm.reshape(-1, 28*28)
x_test_mnist_flat = x_test_mnist_norm.reshape(-1, 28*28)

# One-hot encode the labels
y_train_mnist_one_hot = keras.utils.to_categorical(y_train_mnist, num_classes=10)
y_test_mnist_one_hot = keras.utils.to_categorical(y_test_mnist, num_classes=10)

print(f"Normalized and flattened MNIST Training data shape: {x_train_mnist_flat.shape}")
print(f"One-hot encoded MNIST Training labels shape: {y_train_mnist_one_hot.shape}")
print(f"Normalized and flattened MNIST Test data shape: {x_test_mnist_flat.shape}")
print(f"One-hot encoded MNIST Test labels shape: {y_test_mnist_one_hot.shape}")
# Out:
# Normalized and flattened MNIST Training data shape: (60000, 784)
# One-hot encoded MNIST Training labels shape: (60000, 10)
# Normalized and flattened MNIST Test data shape: (10000, 784)
# One-hot encoded MNIST Test labels shape: (10000, 10)
